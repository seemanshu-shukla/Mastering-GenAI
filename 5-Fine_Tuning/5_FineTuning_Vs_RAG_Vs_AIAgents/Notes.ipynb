# %% [markdown]
# # * <u>Simple AI Assistant</u>
# ![alt text](image.png)
#
# # * <u>Fine Tuning</u>
# ![alt text](image-2.png)
#
# # * <u>RAG</u>
# ![alt text](image-3.png))
#
# # * <u>Agents</u>
# #### Check AI Agents and Human example below. Agar mujhe office jana hai toh brain(LLM) nhi chalega mere legs(Tools) chalega, brain(LLM) bas reason karke instruction dega ki since mujhe office jana hai toh legs ko use karna padega but brain directly chal kar office nhi jayega.
# #### Also, Say I want to send an email. So LLM an help me write a good email based on instruction but it won't be able to send that email(Action). Sending an email will require an external API which can be treated as tool make whole system a tool calling Agent.
# ![alt text](image-4.png)
# ![alt text](image-5.png)
# ![alt text](image-6.png)
#
#
# # * <u>When to use when</u>
# ![alt text](image-7.png)
# ![alt text](image-8.png)
# ![alt text](image-9.png)
