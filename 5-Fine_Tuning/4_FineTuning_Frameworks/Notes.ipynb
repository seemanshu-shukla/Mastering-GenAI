# %% [markdown]
# * LLM Finetuning Framework
# - Hugging Face for LLM Fine-Tuning
# - DeepSpeed(For Multi GPU Training will fine as a module in other framework or for acceleration)
# - LLaMa Factory
# - Unsloth (Getting popular among community because provides high performance with low memory usage - RAM)
# - Axolotl
# - Coloddal-AI
# - LightLLM/vLLM
# - OpenLLM (BentoML)
# - FastChat (LMSYS)
# - Sky Pilot
#
# Under HuggingFace Docs >> Core ML Libraries >> Transformers, Datasets, Tokenizers, Evaluate and Sentence Transformers are Imp modules
#
# Under Training & Optimization >> Dedicated modules for LLM Finetuning
#
# * LLM Leader Board
#
# * Finetuning Enterprise Level Expectation
#
# *

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
